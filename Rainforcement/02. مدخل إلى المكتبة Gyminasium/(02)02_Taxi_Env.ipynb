# %%
# !pip install gymnasium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 14.1 MB/s eta 0:00:00
# ...

# %%
# استيراد المكتبة
import gymnasium as gym

# تهيئة البيئة
env = gym.make("Taxi-v3", render_mode="rgb_array")

# إعادة تهيئة البيئة للحصول على الحالة الأولية
observation, info = env.reset()

print(observation)
# Out:
# 226

# %%
# إظهار الحالة الأولية
env.render()
# Out:
# array([[[110, 109, 106],
#         [110, 109, 106],
#         [124, 122, 122],
#         ...,
#         [108, 111, 109],
#         [108, 111, 109],
#         [118, 119, 119]],
#
#        [[110, 109, 106],
#         [110, 109, 106],
#         [124, 122, 122],
#         ...,
#         [108, 111, 109],
#         [108, 111, 109],
#         [118, 119, 119]],
#
#        [[114, 116, 115],
#         [114, 116, 115],
#         [126, 127, 126],
#         ...,
#         [112, 113, 111],
#         [112, 113, 111],
#         [118, 117, 115]],
#
#        ...,
#
#        [[116, 115, 116],
#         [116, 115, 116],
#         [106, 107, 108],
#         ...,
#         [113, 115, 114],
#         [113, 115, 114],
#         [117, 114, 117]],
#
#        [[116, 115, 116],
#         [116, 115, 116],
#         [106, 107, 108],
#         ...,
#         [113, 115, 114],
#         [113, 115, 114],
#         [117, 114, 117]],
#
#        [[115, 112, 112],
#         [115, 112, 112],
#         [119, 119, 117],
# ...

# %%
# تهيئة البيئة
env = gym.make("Taxi-v3", render_mode="ansi")
# إعادة تهيئة البيئة للحصول على الحالة الأولية
observation, info = env.reset()
# إظهار الحالة الأولية
grid=env.render()
print(grid)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
# طباعة عدد الأفعال و الحالات
print("State Space ", env.observation_space.n)
print("Action Space ", env.action_space.n)
# Out:
# State Space  500
# Action Space  6

# %%
# تهيئة البيئة
env = gym.make("Taxi-v3", render_mode="ansi")
# تحديد عدد دورات الحلقة
env = gym.wrappers.TimeLimit(env, max_episode_steps=2)
# إعادة تهيئة البيئة للحصول على الحالة الأولية
observation, info = env.reset()
grid=env.render()
i=0
print(i)
print(grid)
# Out:
# 0
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
terminated=False
truncated=False
# إجراء حلقة للتفاعل مع البيئة
while not (terminated or truncated):
     # اختيار فعل عشوائي
    action = env.action_space.sample()
     # تنفيذ الفعل في البيئة
    next_state, reward, terminated, truncated, info = env.step(action)
    # عرض البيئة بعد كل خطوة
    grid=env.render()
    i=i+1
    print(f"step: {i}, next_state: {next_state}, reward: {reward}")
    print(grid)

# إغلاق البيئة بعد الانتهاء
env.close()
# Out:
# step: 1, next_state: 193, reward: -1
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# step: 2, next_state: 193, reward: -10
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)
