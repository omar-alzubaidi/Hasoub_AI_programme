# %%
# !pip install gymnasium
# تنزيل بيئة طائر النطاط
# !pip install flappy_bird_gymnasium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 3.8 MB/s eta 0:00:00
# ...

# %%
# مكتبة التعلم المعزز
# !pip install stable_baselines3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 3.8 MB/s eta 0:00:00
# ...

# %%
# استيراد المكتبات اللازمة
import gymnasium as gym
import flappy_bird_gymnasium

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# صنف التعلم المعزز
from stable_baselines3 import PPO

# %%
# تضمين صنف التتبع
from stable_baselines3.common.monitor import Monitor
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# تضمين صنف التعامل مع عدة بيئات
from stable_baselines3.common.vec_env import DummyVecEnv

# %%
# دالة التقييم
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# إنشاء البيئة
env = gym.make("FlappyBird-v0", render_mode="rgb_array", use_lidar=True)

# %%
# استخدام صنف التتبع
env_wrapped = Monitor(env)
# استخدام صنف تعدد البيئات
env_wrapped = DummyVecEnv([lambda: env_wrapped])

# %%
# التصريح عن نموذج التعلم المعزز
model = PPO("MlpPolicy", env_wrapped, verbose=0)
# عدد دورات التدريب
total_timesteps=2000000
# التدريب
model.learn(total_timesteps=total_timesteps)
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `reset()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /usr/local/lib/python3.10/dist-packages/gymnasium/utils/passive_env_checker.py:158: UserWarning: WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")

# %%
# عدد حلقات التقييم
n_eval_episodes=32
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# تقييم النموذج
mean_reward, std_reward = evaluate_policy(model, env_wrapped, n_eval_episodes=n_eval_episodes)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# Mean reward: 189.69 +/- 137.84

# %%
# مسار مجلد العمل
working_folder='/content/drive/MyDrive/RLModels/'
# اسم الملف
model_file_name=f'ppo_flappybird_RL_model_{total_timesteps}'
# مسار الملف
model_file_name_path= working_folder + model_file_name

# %%
# حفظ النموذج المدرب
model.save(model_file_name_path)
