# %%
import tensorflow as tf

cifar10 = tf.keras.datasets.cifar10

(x_train, y_train), (x_test_val, y_test_val) = cifar10.load_data()
print("x_train.shape: ", x_train.shape)
print("y_train.shape: ", y_train.shape)
print("x_test_val.shape: ", x_test_val.shape)
print("y_test_val.shape: ", y_test_val.shape)
# Out:
# x_train.shape:  (50000, 32, 32, 3)
# y_train.shape:  (50000, 1)
# x_test_val.shape:  (10000, 32, 32, 3)
# y_test_val.shape:  (10000, 1)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

def show_samples(data, labels):
    fig, axes = plt.subplots(3, 4, figsize=(10, 10))

    axes = axes.flatten()

    for i in range(len(axes)):
        
        axes[i].imshow(data[i])
        
        class_index=labels[i][0]
        
        class_name=class_names[class_index]
        axes[i].set_title(class_name)
        
        axes[i].axis('off')  
    
    
    plt.tight_layout()
    
    fig.suptitle("Samples")
    
    plt.show()

show_samples(x_train, y_train)

# %%
from sklearn.model_selection import train_test_split

x_test, x_val, y_test, y_val = train_test_split(x_test_val, y_test_val, test_size=0.5)

# %%
x_train = x_train/255.0
x_test = x_test/255.0
x_val = x_val/255.0

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input

model = Sequential()

model.add(Input(shape=(32, 32, 3)))

model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu'  ))

model.add(Conv2D(32, (3, 3), activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu' ))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=128, epochs=40, validation_data=(x_val, y_val))
# Out:
# Epoch 1/40
# 391/391 [==============================] - 50s 124ms/step - loss: 1.6420 - accuracy: 0.3967 - val_loss: 1.2631 - val_accuracy: 0.5370
# Epoch 2/40
# 391/391 [==============================] - 45s 116ms/step - loss: 1.2456 - accuracy: 0.5536 - val_loss: 1.0987 - val_accuracy: 0.6146
# Epoch 3/40
# 391/391 [==============================] - 46s 117ms/step - loss: 1.0708 - accuracy: 0.6183 - val_loss: 0.9457 - val_accuracy: 0.6670
# Epoch 4/40
# 391/391 [==============================] - 46s 117ms/step - loss: 0.9582 - accuracy: 0.6628 - val_loss: 0.8475 - val_accuracy: 0.7002
# Epoch 5/40
# 391/391 [==============================] - 46s 118ms/step - loss: 0.8675 - accuracy: 0.6947 - val_loss: 0.7845 - val_accuracy: 0.7218
# Epoch 6/40
# 391/391 [==============================] - 46s 117ms/step - loss: 0.8156 - accuracy: 0.7154 - val_loss: 0.7603 - val_accuracy: 0.7318
# Epoch 7/40
# 391/391 [==============================] - 46s 118ms/step - loss: 0.7600 - accuracy: 0.7340 - val_loss: 0.7546 - val_accuracy: 0.7366
# Epoch 8/40
# 391/391 [==============================] - 47s 119ms/step - loss: 0.7261 - accuracy: 0.7449 - val_loss: 0.6987 - val_accuracy: 0.7582
# Epoch 9/40
# 391/391 [==============================] - 46s 118ms/step - loss: 0.7011 - accuracy: 0.7538 - val_loss: 0.6848 - val_accuracy: 0.7620
# Epoch 10/40
# 391/391 [==============================] - 46s 119ms/step - loss: 0.6645 - accuracy: 0.7666 - val_loss: 0.6711 - val_accuracy: 0.7650
# Epoch 11/40
# 391/391 [==============================] - 47s 121ms/step - loss: 0.6363 - accuracy: 0.7750 - val_loss: 0.6657 - val_accuracy: 0.7718
# Epoch 12/40
# 391/391 [==============================] - 46s 119ms/step - loss: 0.6183 - accuracy: 0.7833 - val_loss: 0.6451 - val_accuracy: 0.7742
# Epoch 13/40
# 391/391 [==============================] - 47s 121ms/step - loss: 0.5902 - accuracy: 0.7931 - val_loss: 0.6226 - val_accuracy: 0.7844
# Epoch 14/40
# 391/391 [==============================] - 47s 120ms/step - loss: 0.5681 - accuracy: 0.8012 - val_loss: 0.6386 - val_accuracy: 0.7768
# Epoch 15/40
# 391/391 [==============================] - 47s 120ms/step - loss: 0.5512 - accuracy: 0.8051 - val_loss: 0.6287 - val_accuracy: 0.7856
# Epoch 16/40
# 391/391 [==============================] - 47s 120ms/step - loss: 0.5325 - accuracy: 0.8102 - val_loss: 0.6181 - val_accuracy: 0.7846
# Epoch 17/40
# 391/391 [==============================] - 47s 120ms/step - loss: 0.5202 - accuracy: 0.8162 - val_loss: 0.6071 - val_accuracy: 0.7890
# Epoch 18/40
# 391/391 [==============================] - 48s 124ms/step - loss: 0.5106 - accuracy: 0.8194 - val_loss: 0.6227 - val_accuracy: 0.7882
# Epoch 19/40
# 391/391 [==============================] - 50s 129ms/step - loss: 0.4981 - accuracy: 0.8240 - val_loss: 0.6443 - val_accuracy: 0.7838
# Epoch 20/40
# 391/391 [==============================] - 51s 131ms/step - loss: 0.4730 - accuracy: 0.8315 - val_loss: 0.6058 - val_accuracy: 0.7980
# Epoch 21/40
# 391/391 [==============================] - 51s 132ms/step - loss: 0.4733 - accuracy: 0.8313 - val_loss: 0.5975 - val_accuracy: 0.7944
# Epoch 22/40
# 391/391 [==============================] - 51s 131ms/step - loss: 0.4580 - accuracy: 0.8381 - val_loss: 0.6332 - val_accuracy: 0.7936
# Epoch 23/40
# 391/391 [==============================] - 51s 131ms/step - loss: 0.4468 - accuracy: 0.8410 - val_loss: 0.6224 - val_accuracy: 0.8022
# Epoch 24/40
# 391/391 [==============================] - 53s 135ms/step - loss: 0.4438 - accuracy: 0.8428 - val_loss: 0.5949 - val_accuracy: 0.7966
# Epoch 25/40
# 391/391 [==============================] - 52s 132ms/step - loss: 0.4312 - accuracy: 0.8463 - val_loss: 0.6206 - val_accuracy: 0.7948
# Epoch 26/40
# 391/391 [==============================] - 51s 131ms/step - loss: 0.4197 - accuracy: 0.8507 - val_loss: 0.6157 - val_accuracy: 0.7964
# Epoch 27/40
# 391/391 [==============================] - 48s 122ms/step - loss: 0.4155 - accuracy: 0.8510 - val_loss: 0.6026 - val_accuracy: 0.7988
# Epoch 28/40
# 391/391 [==============================] - 47s 120ms/step - loss: 0.4089 - accuracy: 0.8553 - val_loss: 0.6208 - val_accuracy: 0.7982
# Epoch 29/40
# 391/391 [==============================] - 47s 119ms/step - loss: 0.4117 - accuracy: 0.8530 - val_loss: 0.6078 - val_accuracy: 0.7970
# Epoch 30/40
# 391/391 [==============================] - 47s 119ms/step - loss: 0.3970 - accuracy: 0.8588 - val_loss: 0.6234 - val_accuracy: 0.8016
# Epoch 31/40
# 391/391 [==============================] - 47s 119ms/step - loss: 0.3845 - accuracy: 0.8648 - val_loss: 0.6310 - val_accuracy: 0.7950
# Epoch 32/40
# 391/391 [==============================] - 48s 122ms/step - loss: 0.3833 - accuracy: 0.8634 - val_loss: 0.6779 - val_accuracy: 0.7810
# Epoch 33/40
# 391/391 [==============================] - 47s 121ms/step - loss: 0.3743 - accuracy: 0.8659 - val_loss: 0.6326 - val_accuracy: 0.7938
# Epoch 34/40
# 391/391 [==============================] - 46s 119ms/step - loss: 0.3765 - accuracy: 0.8652 - val_loss: 0.6136 - val_accuracy: 0.7962
# Epoch 35/40
# 391/391 [==============================] - 46s 118ms/step - loss: 0.3637 - accuracy: 0.8715 - val_loss: 0.6325 - val_accuracy: 0.7974
# Epoch 36/40
# 391/391 [==============================] - 47s 119ms/step - loss: 0.3636 - accuracy: 0.8711 - val_loss: 0.6410 - val_accuracy: 0.7976
# Epoch 37/40
# 391/391 [==============================] - 47s 119ms/step - loss: 0.3466 - accuracy: 0.8767 - val_loss: 0.6523 - val_accuracy: 0.7950
# Epoch 38/40
# 391/391 [==============================] - 47s 120ms/step - loss: 0.3504 - accuracy: 0.8752 - val_loss: 0.6315 - val_accuracy: 0.8048
# Epoch 39/40
# 391/391 [==============================] - 46s 119ms/step - loss: 0.3515 - accuracy: 0.8757 - val_loss: 0.6294 - val_accuracy: 0.8042
# Epoch 40/40
# 391/391 [==============================] - 47s 119ms/step - loss: 0.3450 - accuracy: 0.8759 - val_loss: 0.6210 - val_accuracy: 0.8024

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print('Accuracy on test set:', accuracy)
# Out:
# 157/157 [==============================] - 2s 10ms/step - loss: 0.6302 - accuracy: 0.8054
# Accuracy on test set: 0.805400013923645

# %%
# !pip install scikeras

# %%
'''
from sklearn.model_selection import GridSearchCV

from scikeras.wrappers import KerasClassifier

import pandas as pd
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input

def create_model(filters=32,
                 kernel_size=(3, 3), 
                 pool_size=(2, 2),
                 activation='relu', 
                 optimizer='adam',
                 loss='sparse_categorical_crossentropy',
                 dropout_rate=0.25,
                 dense_units=512,
                 dense_dropout_rate=0.5):
    model = Sequential()
    model.add(Input(shape=(32, 32, 3)))
    model.add(Conv2D(filters=filters, kernel_size=kernel_size, activation=activation))
    model.add(Conv2D(filters=filters, kernel_size=kernel_size, activation=activation))
    model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(dropout_rate))
    model.add(Conv2D(filters=2*filters, kernel_size=kernel_size, activation=activation))
    model.add(Conv2D(filters=2*filters, kernel_size=kernel_size, activation=activation))
    model.add(MaxPooling2D(pool_size=pool_size))
    model.add(Dropout(dropout_rate))
    model.add(Flatten())
    model.add(Dense(units=dense_units, activation=activation))
    model.add(Dropout(dense_dropout_rate))
    model.add(Dense(10, activation='softmax'))
    
    model.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])
    return model


model_class_keras = KerasClassifier(model=create_model, verbose=0)

param_grid = {
    'model__filters': [32, 64],
    'model__kernel_size': [(3, 3),(4,4) ],
    'model__pool_size': [(2, 2), (4,4)],
    'model__activation': ['relu'],
    'model__optimizer': ['adam'],
    'model__loss': ['sparse_categorical_crossentropy'],
    'model__dropout_rate': [0.2, 0.25],
    'model__dense_units': [256, 512],
    'model__dense_dropout_rate': [0.4, 0.5]
}

cv =5

grid = GridSearchCV(estimator=model_class_keras, param_grid=param_grid, cv=cv, verbose=0)

grid_result = grid.fit(x_train, y_train)

results_df = pd.DataFrame(grid_result.cv_results_)

results_df.to_csv('grid_search_results.csv', index=False)

'''

# %%
# grid_result.best_params_

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input

model = Sequential()

model.add(Input(shape=(32, 32, 3)))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'  ))

model.add(Conv2D(64, (3, 3), activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.2))

model.add(Conv2D(128, (3, 3), activation='relu' ))
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))


model.add(Flatten())

model.add(Dense(512, activation='relu'))

model.add(Dropout(0.4))

model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, batch_size=128, epochs=40, validation_data=(x_val, y_val))
# Out:
# Epoch 1/40
# 391/391 [==============================] - 100s 253ms/step - loss: 1.5554 - accuracy: 0.4300 - val_loss: 1.2186 - val_accuracy: 0.5606
# Epoch 2/40
# 391/391 [==============================] - 97s 248ms/step - loss: 1.1279 - accuracy: 0.5967 - val_loss: 1.0212 - val_accuracy: 0.6382
# Epoch 3/40
# 391/391 [==============================] - 98s 251ms/step - loss: 0.9397 - accuracy: 0.6694 - val_loss: 0.8162 - val_accuracy: 0.7036
# Epoch 4/40
# 391/391 [==============================] - 98s 250ms/step - loss: 0.8202 - accuracy: 0.7141 - val_loss: 0.8454 - val_accuracy: 0.7122
# Epoch 5/40
# 391/391 [==============================] - 98s 250ms/step - loss: 0.7270 - accuracy: 0.7443 - val_loss: 0.7038 - val_accuracy: 0.7558
# Epoch 6/40
# 391/391 [==============================] - 98s 251ms/step - loss: 0.6627 - accuracy: 0.7664 - val_loss: 0.6959 - val_accuracy: 0.7608
# Epoch 7/40
# 391/391 [==============================] - 98s 251ms/step - loss: 0.6139 - accuracy: 0.7830 - val_loss: 0.6537 - val_accuracy: 0.7690
# Epoch 8/40
# 391/391 [==============================] - 98s 251ms/step - loss: 0.5600 - accuracy: 0.8049 - val_loss: 0.6496 - val_accuracy: 0.7746
# Epoch 9/40
# 391/391 [==============================] - 101s 259ms/step - loss: 0.5159 - accuracy: 0.8173 - val_loss: 0.5977 - val_accuracy: 0.7878
# Epoch 10/40
# 391/391 [==============================] - 100s 255ms/step - loss: 0.4767 - accuracy: 0.8301 - val_loss: 0.6083 - val_accuracy: 0.7932
# Epoch 11/40
# 391/391 [==============================] - 100s 255ms/step - loss: 0.4481 - accuracy: 0.8434 - val_loss: 0.5971 - val_accuracy: 0.7998
# Epoch 12/40
# 391/391 [==============================] - 98s 251ms/step - loss: 0.4144 - accuracy: 0.8528 - val_loss: 0.6044 - val_accuracy: 0.7976
# Epoch 13/40
# 391/391 [==============================] - 98s 250ms/step - loss: 0.3868 - accuracy: 0.8621 - val_loss: 0.6130 - val_accuracy: 0.8042
# Epoch 14/40
# 391/391 [==============================] - 97s 249ms/step - loss: 0.3651 - accuracy: 0.8712 - val_loss: 0.6226 - val_accuracy: 0.7996
# Epoch 15/40
# 391/391 [==============================] - 97s 249ms/step - loss: 0.3400 - accuracy: 0.8788 - val_loss: 0.6280 - val_accuracy: 0.8062
# Epoch 16/40
# 391/391 [==============================] - 97s 249ms/step - loss: 0.3250 - accuracy: 0.8847 - val_loss: 0.6237 - val_accuracy: 0.8038
# Epoch 17/40
# 391/391 [==============================] - 97s 249ms/step - loss: 0.3076 - accuracy: 0.8912 - val_loss: 0.6347 - val_accuracy: 0.8012
# Epoch 18/40
# 391/391 [==============================] - 97s 248ms/step - loss: 0.2897 - accuracy: 0.8989 - val_loss: 0.6442 - val_accuracy: 0.8034
# Epoch 19/40
# 391/391 [==============================] - 101s 259ms/step - loss: 0.2740 - accuracy: 0.9024 - val_loss: 0.6635 - val_accuracy: 0.8044
# Epoch 20/40
# 391/391 [==============================] - 103s 264ms/step - loss: 0.2627 - accuracy: 0.9059 - val_loss: 0.6196 - val_accuracy: 0.8100
# Epoch 21/40
# 391/391 [==============================] - 105s 269ms/step - loss: 0.2588 - accuracy: 0.9092 - val_loss: 0.6296 - val_accuracy: 0.8122
# Epoch 22/40
# 391/391 [==============================] - 98s 252ms/step - loss: 0.2484 - accuracy: 0.9107 - val_loss: 0.6264 - val_accuracy: 0.8160
# Epoch 23/40
# 391/391 [==============================] - 98s 252ms/step - loss: 0.2360 - accuracy: 0.9166 - val_loss: 0.6520 - val_accuracy: 0.8134
# Epoch 24/40
# 391/391 [==============================] - 98s 251ms/step - loss: 0.2282 - accuracy: 0.9189 - val_loss: 0.6461 - val_accuracy: 0.8126
# Epoch 25/40
# 391/391 [==============================] - 99s 252ms/step - loss: 0.2207 - accuracy: 0.9215 - val_loss: 0.6533 - val_accuracy: 0.8154
# Epoch 26/40
# 391/391 [==============================] - 99s 254ms/step - loss: 0.2147 - accuracy: 0.9238 - val_loss: 0.6946 - val_accuracy: 0.8086
# Epoch 27/40
# 391/391 [==============================] - 98s 252ms/step - loss: 0.2064 - accuracy: 0.9264 - val_loss: 0.7148 - val_accuracy: 0.8094
# Epoch 28/40
# 391/391 [==============================] - 100s 255ms/step - loss: 0.2146 - accuracy: 0.9237 - val_loss: 0.7017 - val_accuracy: 0.8134
# Epoch 29/40
# 391/391 [==============================] - 100s 255ms/step - loss: 0.1944 - accuracy: 0.9313 - val_loss: 0.7026 - val_accuracy: 0.8122
# Epoch 30/40
# 391/391 [==============================] - 104s 267ms/step - loss: 0.1965 - accuracy: 0.9305 - val_loss: 0.7017 - val_accuracy: 0.8110
# Epoch 31/40
# 391/391 [==============================] - 113s 288ms/step - loss: 0.1917 - accuracy: 0.9327 - val_loss: 0.7039 - val_accuracy: 0.8126
# Epoch 32/40
# 391/391 [==============================] - 109s 280ms/step - loss: 0.1887 - accuracy: 0.9334 - val_loss: 0.7152 - val_accuracy: 0.8038
# Epoch 33/40
# 391/391 [==============================] - 105s 269ms/step - loss: 0.1878 - accuracy: 0.9351 - val_loss: 0.7453 - val_accuracy: 0.8070
# Epoch 34/40
# 391/391 [==============================] - 105s 269ms/step - loss: 0.1763 - accuracy: 0.9387 - val_loss: 0.7690 - val_accuracy: 0.8128
# Epoch 35/40
# 391/391 [==============================] - 108s 275ms/step - loss: 0.1769 - accuracy: 0.9383 - val_loss: 0.7217 - val_accuracy: 0.8118
# Epoch 36/40
# 391/391 [==============================] - 113s 288ms/step - loss: 0.1779 - accuracy: 0.9373 - val_loss: 0.7421 - val_accuracy: 0.8100
# Epoch 37/40
# 391/391 [==============================] - 113s 289ms/step - loss: 0.1754 - accuracy: 0.9391 - val_loss: 0.7397 - val_accuracy: 0.8066
# Epoch 38/40
# 391/391 [==============================] - 117s 298ms/step - loss: 0.1755 - accuracy: 0.9399 - val_loss: 0.7753 - val_accuracy: 0.8040
# Epoch 39/40
# 391/391 [==============================] - 105s 268ms/step - loss: 0.1692 - accuracy: 0.9418 - val_loss: 0.7281 - val_accuracy: 0.8130
# Epoch 40/40
# 391/391 [==============================] - 104s 267ms/step - loss: 0.1580 - accuracy: 0.9446 - val_loss: 0.8009 - val_accuracy: 0.8022

# %%
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

print("Train Accuracy:", train_accuracy[-1])
print("Validation Accuracy:", val_accuracy[-1])
# Out:
# Train Accuracy: 0.9446399807929993
# Validation Accuracy: 0.8022000193595886

# %%
model.save('cifar10_trained_model.keras')

# %%
from keras.models import load_model

model = load_model('cifar10_trained_model.keras')

# %%
import matplotlib.pyplot as plt
import numpy as np

num_images = 20
x_test_selected = x_test[:num_images]
y_test_selected = y_test[:num_images]

predictions = model.predict(x_test_selected)
predicted_labels = np.argmax(predictions, axis=1)

fig, axes = plt.subplots(4, 5, figsize=(12, 10))
axes = axes.ravel()

for i in range(num_images):
    
    axes[i].imshow(x_test_selected[i])
    axes[i].axis('off')
    
    predicted_label = class_names[predicted_labels[i]]
    true_label = class_names[y_test_selected[i][0]]
    
    if predicted_label == true_label:
        title_color = 'green'
    else:
        title_color = 'red'
    
    axes[i].set_title(f'Pred: {predicted_label}\nTrue: {true_label}', color=title_color)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 122ms/step

# %%
for i in range(10):
    image = x_test[i]
    label = class_names[y_test[i][0]]
    
    file_name = f'image_{i}_label_{label}.png'
    plt.imsave(file_name, image)

# %%
image_path = 'image_5_label_bird.png'

# %%
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import numpy as np

image = load_img(image_path, target_size=(32, 32))

image_array = img_to_array(image)

image_array = np.expand_dims(image_array, axis=0)

image_array = image_array / 255.0

# %%
image_array.shape
# Out:
# (1, 32, 32, 3)

# %%
predictions = model.predict([image_array])
# print(predictions[0])

predicted_class = np.argmax(predictions[0])

predicted_label = class_names[predicted_class]
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
plt.imshow(image)
plt.title(predicted_label)
plt.axis('off')
plt.show()
